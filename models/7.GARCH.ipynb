# %% [markdown]
# **SESIÓN 06** | MÁSTER UNIVERSITARIO EN CIENCIA DE DATOS | **CUNEF UNIVERSIDAD**
#
# `v2.2B`
# ---

# %%
## Volatilidad: Modelos GARCH
## Series Temporales
## Volatilidad IBM

# %%
# SOLO EJECUTAR EN COLAB
import os, sys
from google.colab import drive
drive.mount('/content/mnt', force_remount=True)
nb_path = '/content/notebooks'
os.symlink('/content/mnt/My Drive/Colab Notebooks/Librerias', nb_path)
#sys.path.insert(0, nb_path)  # or append(nb_path)
sys.path.append(nb_path)  # or append(nb_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # SOLO EJECUTAR EN COLAB
#       2 import os, sys
# ----> 3 from google.colab import drive
#       4 drive.mount('/content/mnt', force_remount=True)
#       5 nb_path = '/content/notebooks'
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  # Introducción

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read Data
df = pd.read_csv('/content/mnt/My Drive/Colab Notebooks/Series Temporales/S06/IBM.csv')
df.tail()
# Out:
#             Date        High         Low        Open       Close     Volume  \
# 5467  2021-09-24  138.479996  136.750000  137.029999  137.490005  2964400.0
# 5468  2021-09-27  139.070007  137.479996  137.960007  138.559998  3306900.0
# 5469  2021-09-28  139.690002  137.210007  139.169998  137.470001  4314600.0
# 5470  2021-09-29  139.929993  136.440002  137.729996  139.179993  3773900.0
# 5471  2021-09-30  140.570007  138.500000  140.000000  138.929993  5822400.0
#
#        Adj Close
# 5467  137.490005
# 5468  138.559998
# 5469  137.470001
# 5470  139.179993
# 5471  138.929993

# %%
# Select Close adjusted
data=df[['Date', 'Adj Close']].rename(columns={'Adj Close': 'Price'})
data['Date']=pd.to_datetime(data['Date'])
data=data.set_index('Date')
data.tail()
# Out:
#                  Price
# Date
# 2021-09-24  137.490005
# 2021-09-27  138.559998
# 2021-09-28  137.470001
# 2021-09-29  139.179993
# 2021-09-30  138.929993

# %%
# Seaborn plot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)})

# %%
# Plot stock prices
ax = data.Price.plot( linestyle='-')
ax.set_ylabel('IBM');

# %% [markdown]
#  <div class="hr1"></div>
#  # Calculate Daily Logarithmic Return and Squared
#  <div class="hr1"></div>

# %%
# Log return
#
data['log_ret'] =np.log(data.Price).diff()
data.tail()
# Out:
#                  Price   log_ret
# Date
# 2021-09-24  137.490005  0.005543
# 2021-09-27  138.559998  0.007752
# 2021-09-28  137.470001 -0.007898
# 2021-09-29  139.179993  0.012362
# 2021-09-30  138.929993 -0.001798

# %%
# Squared Log return
# Proxy Volatility

data['Squared'] =data['log_ret']**2
data.tail()
# Out:
#                  Price   log_ret   Squared
# Date
# 2021-09-24  137.490005  0.005543  0.000031
# 2021-09-27  138.559998  0.007752  0.000060
# 2021-09-28  137.470001 -0.007898  0.000062
# 2021-09-29  139.179993  0.012362  0.000153
# 2021-09-30  138.929993 -0.001798  0.000003

# %% [markdown]
#  <div class="hr1"></div>
#  #Plot return squared
#  <div class="hr1"></div>

# %%
#
#
fig = plt.figure(figsize=(10,10))
plt.subplot(311)
ax=data.Price.plot( linestyle='-')
ax.set_ylabel('IBM')
ax.set_xlabel('')
ax.set_title('IBM', y=1, fontsize = 16)
plt.subplot(312)
ax=data.log_ret.plot( linestyle='-')
ax.set_ylabel('Rentabilidad')
ax.set_xlabel('')
ax.set_title('Rentabilidad', y=0.8, x=0.6,fontsize = 16)
plt.subplot(313)
ax=data.Squared.plot( linestyle='-')
ax.set_ylabel('IBM')
ax.set_xlabel('')
ax.set_title('Volatilidad', y=0.8, fontsize = 16)
# Out:
# Text(0.5, 0.8, 'Volatilidad')

# %% [markdown]
#  <div class="hr1"></div>
#  ## Testing mean
#  <div class="hr1"></div>

# %%
# mean zero test
from scipy import stats
alpha=0.05
t, p =stats.ttest_1samp(data['log_ret'].dropna(),0.0)
print ('Estadítico t:',t)
print ('p-value:',p)

if  p < alpha:
    print (f'Con {alpha} de significación: Rechazamos la hipotesis de media cero.')
else:
    print (f'Con {alpha} de significación: No podemos rechazar la hipotesis de media cero.')
# Out:
# Estadítico t: 0.542759772252212
# p-value: 0.5873173271424005
# Con 0.05 de significación: No podemos rechazar la hipotesis de media cero.

# %% [markdown]
#  <div class="hr1"></div>
#  ## ACF y PACF
#  ## Ljung-Box Test
#  <div class="hr1"></div>

# %%
# Autocorrelation Fuction Original Time Series
from sktime.utils.plotting import plot_correlations

# %%
# Create proxy Volatility 
ibm_vol=data['Squared'].astype('float64').to_period('D').sort_index().dropna()
ibm_vol.tail()
# Out:
# Date
# 2021-09-24    0.000031
# 2021-09-27    0.000060
# 2021-09-28    0.000062
# 2021-09-29    0.000153
# 2021-09-30    0.000003
# Freq: D, Name: Squared, dtype: float64

# %%
# Plot Autocorrelation
plot_correlations(ibm_vol)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ed70440d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ed78b1d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ed2872bd0>],
#        dtype=object))

# %%
# import function test Ljung_Box
import statsmodels.api as sm
test_Ljung_Box=sm.stats.acorr_ljungbox

# %%
#
# testing Ljung-Box
# H0 NO GARCH
# H1 GARCH
# pvalue < alpha -> No Ruido Blanco -> GARCH
test_Ljung_Box(ibm_vol, lags=[10,20,30], return_df=True)
# Out:
#         lb_stat      lb_pvalue
# 10  1316.257414  1.185796e-276
# 20  2047.259372   0.000000e+00
# 30  2398.015047   0.000000e+00

# %% [markdown]
#  <div class="hr1"></div>
#  ## LM test
#  <div class="hr1"></div>

# %%
# import function test LM-Arch
import statsmodels.api as sm
test_LM_ARCH=sm.stats.diagnostic.het_arch

# %%
#
# testing LM-ARCH
# pvalue < alpha -> ARCH
# MANU: Rechazamos hipótesis nula porque el pvalor es menor de 0.05
lm, lmpval, f, pval, result_int =test_LM_ARCH(data['log_ret'].dropna(), nlags=20, store=True)
print ('Estadístico LM: ', lm)
print ('p-value: ', lmpval)
print ('Estadístico F: ', f)
print ('p-value: ', pval)
# Out:
# Estadístico LM:  619.9267426561952
# p-value:  1.8171989001942578e-118
# Estadístico F:  34.83907232731476
# p-value:  3.243874829088287e-126

# %%
#
result_int.resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     34.84
# Date:                Sun, 06 Nov 2022   Prob (F-statistic):          3.24e-126
# Time:                        14:57:18   Log-Likelihood:                 30838.
# No. Observations:                5451   AIC:                        -6.163e+04
# Df Residuals:                    5430   BIC:                        -6.150e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.093e-05    1.4e-05      5.760      0.000    5.34e-05       0.000
# x1             0.0567      0.014      4.181      0.000       0.030       0.083
# x2             0.0859      0.014      6.321      0.000       0.059       0.113
# x3             0.0780      0.014      5.715      0.000       0.051       0.105
# x4             0.0784      0.014      5.742      0.000       0.052       0.105
# x5             0.0422      0.014      3.082      0.002       0.015       0.069
# x6             0.0640      0.014      4.675      0.000       0.037       0.091
# x7            -0.0105      0.014     -0.764      0.445      -0.037       0.016
# x8             0.0547      0.014      3.987      0.000       0.028       0.082
# x9             0.0414      0.014      3.013      0.003       0.014       0.068
# x10            0.0459      0.014      3.344      0.001       0.019       0.073
# x11            0.0568      0.014      4.138      0.000       0.030       0.084
# x12            0.0263      0.014      1.919      0.055      -0.001       0.053
# x13           -0.0235      0.014     -1.713      0.087      -0.050       0.003
# x14           -0.0125      0.014     -0.911      0.363      -0.039       0.014
# x15            0.0133      0.014      0.972      0.331      -0.014       0.040
# x16            0.0420      0.014      3.071      0.002       0.015       0.069
# x17            0.0714      0.014      5.234      0.000       0.045       0.098
# x18            0.0044      0.014      0.326      0.744      -0.022       0.031
# x19           -0.0035      0.014     -0.257      0.797      -0.030       0.023
# x20           -0.0058      0.014     -0.426      0.670      -0.032       0.021
# ==============================================================================
# Omnibus:                     9660.186   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17444988.075
# Skew:                          12.433   Prob(JB):                         0.00
# Kurtosis:                     279.025   Cond. No.                     1.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## ARCH(1)

# %%
# https://github.com/bashtage/arch/
# pip install arch

# %%
#MANU: aviso a navegantes: empecemos probando a GARCH (1,1), y si no funciona, ya vamos con el ARCH (1,1),

from arch.univariate import ARX
from arch.univariate import ARCH, GARCH

# %%
# Modelo para la Media un AR(1)
ar = ARX(100*data['log_ret'].dropna(), lags=[1])
print(ar.fit().summary())
# Out:
#                      AR - Constant Variance Model Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.003
# Mean Model:                        AR   Adj. R-squared:                  0.002
# Vol Model:          Constant Variance   Log-Likelihood:               -10534.0
# Distribution:                  Normal   AIC:                           21074.1
# Method:            Maximum Likelihood   BIC:                           21093.9
#                                         No. Observations:                 5470
# Date:                Sun, Nov 06 2022   Df Residuals:                     5468
# Time:                        14:57:33   Df Model:                            2
#                                   Mean Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const          0.0135  2.247e-02      0.599      0.549  [-3.059e-02,5.750e-02]
# log_ret[1]    -0.0507  2.156e-02     -2.350  1.875e-02 [-9.292e-02,-8.418e-03]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# sigma2         2.7558      0.121     22.732 2.157e-114 [  2.518,  2.993]
# ========================================================================
#
# Covariance estimator: White's Heteroskedasticity Consistent Estimator

# %%
#
fig = res.plot(annualize="D")

# %%
# MODELO ERRONEO
# ARCH(1)
ar.volatility = ARCH(p=1)
res = ar.fit(update_freq=0, disp="off")
print(res.summary())
# Out:
#                            AR - ARCH Model Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.002
# Mean Model:                        AR   Adj. R-squared:                  0.002
# Vol Model:                       ARCH   Log-Likelihood:               -10169.3
# Distribution:                  Normal   AIC:                           20346.5
# Method:            Maximum Likelihood   BIC:                           20373.0
#                                         No. Observations:                 5470
# Date:                Sun, Nov 06 2022   Df Residuals:                     5468
# Time:                        14:57:33   Df Model:                            2
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# Const          0.0335  2.368e-02      1.415      0.157 [-1.291e-02,7.991e-02]
# log_ret[1]    -0.0764  7.393e-02     -1.033      0.302    [ -0.221,6.852e-02]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega          1.7280  9.701e-02     17.813  5.629e-71 [  1.538,  1.918]
# alpha[1]       0.4473  7.220e-02      6.195  5.819e-10 [  0.306,  0.589]
# ========================================================================
#
# Covariance estimator: robust

# %%
# Análisis Residuos
mod1_std_resid=(res.resid / res.conditional_volatility).astype('float64').to_period('D').sort_index().dropna()

# %%
#TENEMOS QUE COMPROBAR
- Que Z sea RB
- Que Z^2 sea RB
- Que Z sea normal

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid)

# #lo que él pone en clase:
# pl,ax=plot_correlations(mod1_std_resid, zero_lag=False)
# ax[2].set_ylim(-.25, .25)
# ax[2].set_ylim(-.25, .25)
##las gráficas se modificarán y se cumplirán. La primera correlación es cero, por eso la hemos quitado.
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec04995d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec020ba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec0449ad0>],
#        dtype=object))

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid**2)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec034af50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec005e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec0022950>],
#        dtype=object))

# %%
#
# testing Ljung-Box
# pvalue < alpha -> No Ruido Blanco
test_Ljung_Box(mod1_std_resid**2, lags=[10,20,30], return_df=True)
# Out:
#        lb_stat      lb_pvalue
# 10  253.263435   1.117709e-48
# 20  486.911753   1.595013e-90
# 30  604.498277  3.468119e-108

# %%
# qqplot
sm.qqplot(mod1_std_resid,line='45')
plt.show()
#No sigue una distribución normal porque no están pegadas a la línea.

# %% [markdown]
# # <div class="hr1"></div>
#  ## GARCH(1,1)
#  <div class="hr1"></div>

# %%
#
ar = ARX(100*data['log_ret'].dropna(), lags=[1])
print(ar.fit().summary())
# Out:
#                      AR - Constant Variance Model Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.003
# Mean Model:                        AR   Adj. R-squared:                  0.002
# Vol Model:          Constant Variance   Log-Likelihood:               -10534.0
# Distribution:                  Normal   AIC:                           21074.1
# Method:            Maximum Likelihood   BIC:                           21093.9
#                                         No. Observations:                 5470
# Date:                Sun, Nov 06 2022   Df Residuals:                     5468
# Time:                        14:57:42   Df Model:                            2
#                                   Mean Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const          0.0135  2.247e-02      0.599      0.549  [-3.059e-02,5.750e-02]
# log_ret[1]    -0.0507  2.156e-02     -2.350  1.875e-02 [-9.292e-02,-8.418e-03]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# sigma2         2.7558      0.121     22.732 2.157e-114 [  2.518,  2.993]
# ========================================================================
#
# Covariance estimator: White's Heteroskedasticity Consistent Estimator

# %%
# MODELO 
# GARCH(1,1)
ar.volatility = GARCH(p=1,q=1)
res = ar.fit(update_freq=0, disp="off")
print(res.summary())
# Out:
#                            AR - GARCH Model Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.001
# Mean Model:                        AR   Adj. R-squared:                  0.001
# Vol Model:                      GARCH   Log-Likelihood:               -9673.42
# Distribution:                  Normal   AIC:                           19356.8
# Method:            Maximum Likelihood   BIC:                           19389.9
#                                         No. Observations:                 5470
# Date:                Sun, Nov 06 2022   Df Residuals:                     5468
# Time:                        14:57:42   Df Model:                            2
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# Const          0.0359  1.909e-02      1.879  6.018e-02 [-1.537e-03,7.330e-02]
# log_ret[1]    -0.0122  1.606e-02     -0.762      0.446 [-4.372e-02,1.923e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0999  2.790e-02      3.582  3.409e-04 [4.525e-02,  0.155]
# alpha[1]       0.1210  2.698e-02      4.484  7.327e-06 [6.810e-02,  0.174]
# beta[1]        0.8427  3.061e-02     27.531 7.557e-167   [  0.783,  0.903]
# ==========================================================================
#
# Covariance estimator: robust

# %%
#Alpha y omega suman 0.96, así que parece que pinta bien

# %%
#
fig = res.plot(annualize="D")

# %%
# Análisis Residuos
mod1_std_resid=(res.resid / res.conditional_volatility).astype('float64').to_period('D').sort_index().dropna()

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ed703dd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebfdeecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebffb6fd0>],
#        dtype=object))

# %%
#Mucho más RB

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid**2)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec0249e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebff02a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebfebdad0>],
#        dtype=object))

# %%
#Mucho más RB, el GARCH (1,1) es correcto. Otra cosa es que habrá que probar la distribución

# %%
#
# testing Ljung-Box
# pvalue < alpha -> No Ruido Blanco
test_Ljung_Box(mod1_std_resid**2, lags=[10,20,30], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 10   6.849819   0.739543
# 20  12.634537   0.892508
# 30  14.568371   0.991960

# %%
# qqplot
sm.qqplot(mod1_std_resid,line='45')
plt.show()

# %%
#MANU: Tenemos un problema, es un modelo GARCH pero no cumple con la distribución normal. Probamos con una T de student.

# %% [markdown]
# # <div class="hr1"></div>
#  ## GARCH(1,1) + t-student
#  <div class="hr1"></div>

# %%
#
from arch.univariate import StudentsT

# %%
#
ar.distribution = StudentsT()
res = ar.fit(update_freq=0, disp="off")
print(res.summary())
# Out:
#                               AR - GARCH Model Results
# ====================================================================================
# Dep. Variable:                      log_ret   R-squared:                       0.002
# Mean Model:                              AR   Adj. R-squared:                  0.002
# Vol Model:                            GARCH   Log-Likelihood:               -9271.27
# Distribution:      Standardized Student's t   AIC:                           18554.5
# Method:                  Maximum Likelihood   BIC:                           18594.2
#                                               No. Observations:                 5470
# Date:                      Sun, Nov 06 2022   Df Residuals:                     5468
# Time:                              14:57:50   Df Model:                            2
#                                   Mean Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const          0.0405  1.458e-02      2.777  5.482e-03   [1.192e-02,6.909e-02]
# log_ret[1]    -0.0324  1.339e-02     -2.417  1.564e-02 [-5.861e-02,-6.123e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0323  1.294e-02      2.494  1.262e-02 [6.914e-03,5.763e-02]
# alpha[1]       0.0800  2.130e-02      3.757  1.720e-04   [3.828e-02,  0.122]
# beta[1]        0.9101  2.380e-02     38.243      0.000     [  0.863,  0.957]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             4.4772      0.283     15.819  2.298e-56 [  3.922,  5.032]
# ========================================================================
#
# Covariance estimator: robust

# %%
#
fig = res.plot(annualize="D")

# %%
# Análisis Residuos
mod1_std_resid=(res.resid / res.conditional_volatility).astype('float64').to_period('D').sort_index().dropna()

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid)

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid**2)

# %%
#
# testing Ljung-Box
# pvalue < alpha -> No Ruido Blanco
test_Ljung_Box(mod1_std_resid**2, lags=[10,20,30], return_df=True)

# %%
# qqplot normal
sm.qqplot(mod1_std_resid,line='45')
plt.show()

# %%
# qqplot t-student
sm.qqplot(mod1_std_resid,dist=stats.t,fit=True,line='45')
plt.show()
#MANU: casi, se arregla mucho pero no del todo porque es asimétrica (como casi todo). En python no hay qqplot para las asimétricas.

# %% [markdown]
# T-STUDENT ASIMETRICA

# %%
from arch import arch_model
model1=arch_model(100*data['log_ret'].dropna(), p = 1, q = 1,
          mean = 'AR', lags=1, vol = 'GARCH',
          dist = 'skewt')
res = model1.fit(update_freq=0, disp="off")
print(res.summary())
# Out:
#                                  AR - GARCH Model Results
# =========================================================================================
# Dep. Variable:                           log_ret   R-squared:                       0.002
# Mean Model:                                   AR   Adj. R-squared:                  0.002
# Vol Model:                                 GARCH   Log-Likelihood:               -9269.51
# Distribution:      Standardized Skew Student's t   AIC:                           18553.0
# Method:                       Maximum Likelihood   BIC:                           18599.3
#                                                    No. Observations:                 5470
# Date:                           Sun, Nov 06 2022   Df Residuals:                     5468
# Time:                                   15:10:49   Df Model:                            2
#                                   Mean Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const          0.0279  1.593e-02      1.750  8.013e-02  [-3.346e-03,5.910e-02]
# log_ret[1]    -0.0339  1.344e-02     -2.525  1.156e-02 [-6.027e-02,-7.595e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0316  1.277e-02      2.478  1.320e-02 [6.619e-03,5.667e-02]
# alpha[1]       0.0789  2.103e-02      3.754  1.741e-04   [3.773e-02,  0.120]
# beta[1]        0.9112  2.359e-02     38.619      0.000     [  0.865,  0.957]
#                                  Distribution
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# eta            4.4914      0.284     15.825  2.105e-56      [  3.935,  5.048]
# lambda        -0.0358  1.976e-02     -1.810  7.032e-02 [-7.449e-02,2.966e-03]
# =============================================================================
#
# Covariance estimator: robust

# %%
#
fig = res.plot(annualize="D")

# %%
# Análisis Residuos
mod1_std_resid=(res.resid / res.conditional_volatility).astype('float64').to_period('D').sort_index().dropna()

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebee829d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebee3a890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebedf78d0>],
#        dtype=object))

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid**2)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebee8c410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebeed7650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2ebfac5650>],
#        dtype=object))

# %%
#
# testing Ljung-Box
# pvalue < alpha -> No Ruido Blanco
test_Ljung_Box(mod1_std_resid**2, lags=[10,20,30], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 10   4.042583   0.945406
# 20  12.069697   0.913656
# 30  17.531877   0.965631

# %%
(1.5*res.conditional_volatility)["2020":].plot()
(-1.5*res.conditional_volatility)["2020":].plot()
(100*data['log_ret'].dropna())["2020":].plot()
#Se salen16 datos en 2 años
#Ese 1,5 es el intervalo de confianza (ver dónde esta el 1,5 en la distribución normal)

# %% [markdown]
# # <div class="hr1"></div>
#  ## Forecast Volatility
#  <div class="hr1"></div>

# %%
# Predicción 20 días
forecasts = res.forecast(horizon=20, reindex=False)

# %%
# Mean
forecasts.mean
# Out:
#                 h.01      h.02     h.03      h.04      h.05      h.06  \
# Date
# 2021-09-30  0.033977  0.026724  0.02697  0.026961  0.026962  0.026962
#
#                 h.07      h.08      h.09      h.10      h.11      h.12  \
# Date
# 2021-09-30  0.026962  0.026962  0.026962  0.026962  0.026962  0.026962
#
#                 h.13      h.14      h.15      h.16      h.17      h.18  \
# Date
# 2021-09-30  0.026962  0.026962  0.026962  0.026962  0.026962  0.026962
#
#                 h.19      h.20
# Date
# 2021-09-30  0.026962  0.026962

# %%
# Volatilidad
fvol=((forecasts.variance**0.5)*1*np.sqrt(252)).T #la anualiza por la raiz cuadrada de 252, que son los días laborables de mercado
fvol.plot()
# Out:
#                  h.01       h.02       h.03       h.04       h.05      h.06  \
# Date
# 2021-09-30  16.295132  16.467955  16.628403  16.785747  16.940101  17.09156
#
#                  h.07       h.08       h.09       h.10       h.11       h.12  \
# Date
# 2021-09-30  17.240214  17.386152  17.529453  17.670197  17.808458  17.944306
#
#                 h.13       h.14       h.15       h.16       h.17       h.18  \
# Date
# 2021-09-30  18.07781  18.209033  18.338037  18.464882  18.589623  18.712316
#
#                  h.19       h.20
# Date
# 2021-09-30  18.833012  18.951761

# %%
((forecasts.variance**0.5)*2*np.sqrt(252)).plot
